# %%
from pennylane import broadcast
import torch
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.ticker as mticker
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_moons

# Set random seeds
torch.manual_seed(149)
np.random.seed(149)

X, y = make_moons(n_samples=400, noise=0.1)
y_ = torch.unsqueeze(torch.tensor(y), 1)  # used for one-hot encoded labels
y_hot = torch.scatter(torch.zeros((400, 2)), 1, y_, 1)

c = ["#1f77b4" if y_ == 0 else "#ff7f0e" for y_ in y]  # colours for each class
plt.axis("off")
plt.scatter(X[:, 0], X[:, 1], c=c)
plt.show()

# %%
def H_layer(nqubits):
    """Layer of single-qubit Hadamard gates.
    """
    for idx in range(nqubits):
        qml.Hadamard(wires=idx)

# %%
import pennylane as qml

n_qubits = 10
dev = qml.device("lightning.qubit", wires=n_qubits)

def H_layer(n_qubits):
    for i in range(n_qubits):
        qml.Hadamard(wires=i)

def custom_rot_layer(weights, wires):
    for i, wire in enumerate(wires):
        phi, theta, omega = weights[i]
        qml.Rot(phi, theta, omega, wires=wire)

def entangling_layer(wires, measured_1, measured_2):
    for j in range(len(wires) - 1):
        qml.CNOT(wires=[wires[j], wires[j + 1]])
        qml.cond(measured_1, qml.CRZ)(np.pi / 2, wires=[wires[j], wires[j + 1]])
        qml.cond(measured_2, qml.CRY)(np.pi / 4, wires=[wires[j], wires[j + 1]])

@qml.qnode(dev)
def qnode(inputs, weights, x, z):
    H_layer(n_qubits)

    for i in range(n_layers):
        if i % 2 == 0:
            qml.AngleEmbedding(inputs, wires=range(n_qubits), rotation='Y')
        else:
            qml.AngleEmbedding(inputs, wires=range(n_qubits), rotation='Z')
        
        measured_1 = qml.measure(1)
        measured_2 = qml.measure(2)
        entangling_layer(range(n_qubits), measured_1, measured_2)
        custom_rot_layer(weights[i], range(n_qubits))

    custom_rot_layer(weights[-1], range(n_qubits))
    qml.cond(measured_2, qml.CRZ)(z, wires=(3, 0))
    H_layer(n_qubits)

    return [qml.expval(qml.PauliZ(wires=i)) for i in range(n_qubits)], qml.probs(op=measured_2)

# %%
n_layers = 5
weight_shapes = {"weights": (n_layers, n_qubits)}

# %%
loss_func = torch.nn.L1Loss()

# %%
class HybridModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.clayer_1 = torch.nn.Linear(2, 20)
        # block one
        self.qlayer_1 = qml.qnn.TorchLayer(qnode, weight_shapes)
        # block two
        self.qlayer_2 = qml.qnn.TorchLayer(qnode, weight_shapes)
        self.clayer_2 = torch.nn.Linear(20, 2)
        self.softmax = torch.nn.Softmax(dim=1)

    def forward(self, x):
        x = self.clayer_1(x)
        x_1, x_2 = torch.split(x, 10, dim=1)
        x_1 = self.qlayer_1(x_1)
        x_2 = self.qlayer_2(x_2)
        x = torch.cat([x_1, x_2], axis=1)
        x = self.clayer_2(x)
        return self.softmax(x)

model = HybridModel()

# %%
from sklearn.model_selection import train_test_split

# %%
X = torch.tensor(X, requires_grad=True).float()
y_hot = y_hot.float()

batch_size = 5
batches = 200 // batch_size

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=149)
# Convert data to PyTorch tensors
X_train = torch.tensor(X_train, requires_grad=True).float()
y_ = torch.unsqueeze(torch.tensor(y_train), 1)  # used for one-hot encoded labels
y_train_hot = torch.scatter(torch.zeros((280, 2)), 1, y_, 1)
y_train_hot = y_train_hot.float()

X_test = torch.tensor(X_test, requires_grad=True).float()
y_ = torch.unsqueeze(torch.tensor(y_test), 1)  # used for one-hot encoded labels
y_test_hot = torch.scatter(torch.zeros((120, 2)), 1, y_, 1)
y_test_hot = y_test_hot.float()

train_dataset = TensorDataset(X_train, y_train_hot)
test_dataset = TensorDataset(X_test, y_test_hot)

train_loader = DataLoader(train_dataset, batch_size=5, shuffle=True, drop_last=True)
test_loader = DataLoader(test_dataset, batch_size=5, shuffle=True, drop_last=True)

opt = torch.optim.Adam(model.parameters(), lr=0.0004)

train_acc_history = []
test_acc_history = []

epochs = 100

for epoch in range(epochs):
    train_running_loss = 0
    test_running_loss = 0
    for xs, ys in train_loader:
        opt.zero_grad()

        loss_evaluated = loss_func(model(xs), ys)
        loss_evaluated.backward()

        opt.step()

        train_running_loss += loss_evaluated.item()
        
    train_avg_loss = train_running_loss / batches

    print(f"Train - Epoch {epoch + 1}: Loss: {train_avg_loss:.4f}")

    # Calculate train accuracy
    y_pred_train = model(X_train)
    predictions_train = torch.argmax(y_pred_train, axis=1).detach().numpy()

    correct_train = [1 if p == p_true else 0 for p, p_true in zip(predictions_train, y_train)]
    train_accuracy = sum(correct_train) / len(correct_train)
    print(f"Train Accuracy: {train_accuracy * 100:.2f}%")
    train_acc_history.append(train_accuracy)
    
    # Calculate testmodel.eval()
    with torch.no_grad():
        y_pred_test = model(X_test)
        predictions_test = torch.argmax(y_pred_test, axis=1).detach().numpy()
        correct_test = [1 if p == p_true else 0 for p, p_true in zip(predictions_test, y_test)]
        test_accuracy = sum(correct_test) / len(correct_test)
        print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
        test_acc_history.append(test_accuracy)
# Out:
# /tmp/ipykernel_822935/3260888472.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X = torch.tensor(X, requires_grad=True).float()
# /tmp/ipykernel_822935/3260888472.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_train = torch.tensor(X_train, requires_grad=True).float()
# /tmp/ipykernel_822935/3260888472.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_test = torch.tensor(X_test, requires_grad=True).float()
# Train - Epoch 1: Loss: 0.6475
# Train Accuracy: 86.43%
# Test Accuracy: 85.00%
# Train - Epoch 2: Loss: 0.5940
# Train Accuracy: 97.50%
# Test Accuracy: 98.33%
# Train - Epoch 3: Loss: 0.5325
# Train Accuracy: 97.86%
# Test Accuracy: 98.33%
# Train - Epoch 4: Loss: 0.4655
# Train Accuracy: 97.86%
# Test Accuracy: 98.33%
# Train - Epoch
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 84: Loss: 0.0063
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 85: Loss: 0.0059
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 86: Loss: 0.0058
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 87: Loss: 0.0058
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 88: Loss: 0.0058
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 89: Loss: 0.0054
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 90: Loss: 0.0054
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 91: Loss: 0.0054
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 92: Loss: 0.0052
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 93: Loss: 0.0051
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 94: Loss: 0.0049
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 95: Loss: 0.0049
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 96: Loss: 0.0050
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 97: Loss: 0.0047
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 98: Loss: 0.0048
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 99: Loss: 0.0044
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 100: Loss: 0.0045
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%

# %%
# Select every 2nd or 3rd point to make the dots sparser
sparse_train_acc = train_acc_history[::2]  # Every 2nd point
sparse_test_acc = test_acc_history[::2]    # Every 2nd point
sparse_epochs = list(range(0, len(train_acc_history), 2))  # Adjust epochs accordingly

# Plotting the training and testing accuracies
fig, ax = plt.subplots()
ax.plot(sparse_epochs, sparse_train_acc, linestyle='-', marker='^', alpha=.9, ms=6 , label='Train Accuracy', color='C1')
ax.plot(sparse_epochs, sparse_test_acc, linestyle='--', marker='o', alpha=.5, ms=5, label='Test Accuracy', color='C2')
ax.set(title='Training and Testing Accuracy over Epochs', xlabel='Epoch', ylabel='Accuracy')

# Set Y-axis to log scale and limit the range from 50% to 100%
# ax.set_yscale('log')
ax.set_ylim(0.50, 1.01)  # Log scale from 50% to 100%
ax.set_xlim(-2, 100)      # Limit X-axis

# Add grid, legend, and other visual enhancements
ax.grid(True)
ax.legend(bbox_to_anchor=(0.65, 0.75), fontsize=8.5)
ax.axhline(1, ls='--', lw=2, c='m')
ax.text(35, 0.95, '100% train accuracy', c='m')
ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1.0))

# Create the inset of zoomed-out view
axins = inset_axes(ax, width="40%", height="40%", loc="lower right", borderpad=3)

# Plot the zoomed-out view on the inset with sparse points
axins.plot(sparse_epochs, sparse_train_acc, linestyle='-', marker='^', color='C1')
axins.plot(sparse_epochs, sparse_test_acc, linestyle='--', marker='o', color='C2')

# Set limits for the inset (zoomed-out view)
axins.set_xlim(0, len(train_acc_history)/3)
axins.set_ylim(0.85, 1.01)

# Add gridlines and remove ticks to make the inset cleaner
axins.grid(True)
axins.tick_params(left=False, bottom=False)  # Optional: remove ticks on the inset

# Save the figure and show the plot
plt.savefig('plt1.png')
plt.show()

# %%
# Original dataset plot
c = ["#1f77b4" if y_ == 0 else "#ff7f0e" for y_ in y]  # colors for each class
plt.scatter(X[:, 0], X[:, 1], c=c, alpha=0.5, label='Original Data')

# Highlight test points
# Correct predictions in green, incorrect in red
for i in test_indices:
    if y[i] == predictions[i]:
        plt.scatter(X[i, 0], X[i, 1], c='green', edgecolor='k', label='Correct Prediction' if i == test_indices[0] else "")
    else:
        plt.scatter(X[i, 0], X[i, 1], c='red', edgecolor='k', label='Incorrect Prediction' if i == test_indices[0] else "")

plt.axis("off")
plt.legend()
plt.show()
