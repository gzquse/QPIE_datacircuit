# %%
# This cell is added by sphinx-gallery
# It can be customized to whatever you like
# %matplotlib inline
# !pip install pennylane
import time
seconds = time.time()
print("Time in seconds since beginning of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since beginning of run: 1726602099.1940658
# Tue Sep 17 12:41:39 2024

# %%
from pennylane import broadcast
import torch
from torch.utils.data import DataLoader, TensorDataset

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_moons

# Set random seeds
torch.manual_seed(149)
np.random.seed(149)

X, y = make_moons(n_samples=400, noise=0.1)
y_ = torch.unsqueeze(torch.tensor(y), 1)  # used for one-hot encoded labels
y_hot = torch.scatter(torch.zeros((400, 2)), 1, y_, 1)

c = ["#1f77b4" if y_ == 0 else "#ff7f0e" for y_ in y]  # colours for each class
plt.axis("off")
plt.scatter(X[:, 0], X[:, 1], c=c)
plt.show()

# %%
def H_layer(nqubits):
    """Layer of single-qubit Hadamard gates.
    """
    for idx in range(nqubits):
        qml.Hadamard(wires=idx)

# %%
import pennylane as qml

n_qubits = 10
dev = qml.device("default.qubit", wires=n_qubits)

@qml.qnode(dev)
def qnode(inputs, weights):
    H_layer(n_qubits)
    for i in range(n_layers//2):
        qml.AngleEmbedding(inputs, wires=range(n_qubits), rotation='Y')
        qml.AngleEmbedding(inputs, wires=range(n_qubits), rotation='Z')
        qml.AngleEmbedding(inputs, wires=range(n_qubits), rotation='Y')
    H_layer(n_qubits)
    qml.RandomLayers(weights, wires=range(n_qubits), ratio_imprim=0.2, rotations=[qml.RY], seed=149)
    return [qml.expval(qml.PauliZ(wires=i)) for i in range(n_qubits)]

# %%
n_layers = 5
weight_shapes = {"weights": (n_layers, n_qubits)}

# %%
w = np.random.random(size=(n_layers, n_qubits))
fig, ax = qml.draw_mpl(qnode, show_all_wires=True, decimals=2, expansion_strategy="deviceasd")(w,w)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 w = np.random.random(size=(n_layers, n_qubits))
# ----> 2 fig, ax = qml.draw_mpl(qnode, show_all_wires=True, decimals=2, expansion_strategy="deviceasd")(w,w)
#       3 fig.show()
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/drawer/draw.py:759, in _draw_mpl_qnode.<locals>.wrapper(*args, **kwargs_qnode)
#     757 @wraps(qnode)
#     758 def wrapper(*args, **kwargs_qnode):
# --> 759     tapes, _ = qml.workflow.construct_batch(qnode, level=level)(*args, **kwargs_qnode)
#     761     if len(tapes) > 1:
#     762         warnings.warn(
#     763             "Multiple tapes constructed, but only displaying the first one.", UserWarning
#     764         )
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/workflow/construct_batch.py:354, in construct_batch.<locals>.batch_constructor(*args, **kwargs)
#     351     initial_tape.trainable_params = qml.math.get_trainable_indices(params)
#     353 qnode._update_gradient_fn(tape=initial_tape)
# --> 354 program = get_transform_program(qnode, level=level)
#     356 return program((initial_tape,))
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/workflow/construct_batch.py:198, in get_transform_program(qnode, level)
#     196     level = num_user + 1 if getattr(qnode.gradient_fn, "expand_transform", False) else num_user
#     197 elif isinstance(level, str):
# --> 198     raise ValueError(
#     199         f"level {level} not recognized. Acceptable strings are 'device', 'top', 'user', and 'gradient'."
#     200     )
#     202 if level is None or isinstance(level, int):
#     203     level = slice(0, level)
#
# ValueError: level deviceasd not recognized. Acceptable strings are 'device', 'top', 'user', and 'gradient'.

# %%
print(qml.draw(qnode, expansion_strategy="device")(w,w))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(qml.draw(qnode, expansion_strategy="device")(w,w))
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/drawer/draw.py:345, in _draw_qnode.<locals>.wrapper(*args, **kwargs)
#     343 @wraps(qnode)
#     344 def wrapper(*args, **kwargs):
# --> 345     tapes, _ = qml.workflow.construct_batch(qnode, level=level)(*args, **kwargs)
#     347     if wire_order:
#     348         _wire_order = wire_order
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/workflow/construct_batch.py:356, in construct_batch.<locals>.batch_constructor(*args, **kwargs)
#     353 qnode._update_gradient_fn(tape=initial_tape)
#     354 program = get_transform_program(qnode, level=level)
# --> 356 return program((initial_tape,))
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/transforms/core/transform_program.py:515, in TransformProgram.__call__(self, tapes)
#     513 if self._argnums is not None and self._argnums[i] is not None:
#     514     tape.trainable_params = self._argnums[i][j]
# --> 515 new_tapes, fn = transform(tape, *targs, **tkwargs)
#     516 execution_tapes.extend(new_tapes)
#     518 fns.append(fn)
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/devices/preprocess.py:369, in decompose(tape, stopping_condition, stopping_condition_shots, skip_initial_state_prep, decomposer, max_expansion, name, error)
#     366     return (tape,), null_postprocessing
#     367 try:
# --> 369     new_ops = [
#     370         final_op
#     371         for op in tape.operations[len(prep_op) :]
#     372         for final_op in _operator_decomposition_gen(
#     373             op,
#     374             stopping_condition,
#     375             decomposer=decomposer,
#     376             max_expansion=max_expansion,
#     377             name=name,
#     378             error=error,
#     379         )
#     380     ]
#     381 except RecursionError as e:
#     382     raise error(
#     383         "Reached recursion limit trying to decompose operations. "
#     384         "Operator decomposition may have entered an infinite loop."
#     385     ) from e
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/devices/preprocess.py:369, in <listcomp>(.0)
#     366     return (tape,), null_postprocessing
#     367 try:
# --> 369     new_ops = [
#     370         final_op
#     371         for op in tape.operations[len(prep_op) :]
#     372         for final_op in _operator_decomposition_gen(
#     373             op,
#     374             stopping_condition,
#     375             decomposer=decomposer,
#     376             max_expansion=max_expansion,
#     377             name=name,
#     378             error=error,
#     379         )
#     380     ]
#     381 except RecursionError as e:
#     382     raise error(
#     383         "Reached recursion limit trying to decompose operations. "
#     384         "Operator decomposition may have entered an infinite loop."
#     385     ) from e
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/devices/preprocess.py:64, in _operator_decomposition_gen(op, acceptance_function, decomposer, max_expansion, current_depth, name, error)
#      62 else:
#      63     try:
# ---> 64         decomp = decomposer(op)
#      65         current_depth += 1
#      66     except qml.operation.DecompositionUndefinedError as e:
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/devices/preprocess.py:355, in decompose.<locals>.decomposer(op)
#     354 def decomposer(op):
# --> 355     return op.decomposition()
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/operation.py:1337, in Operator.decomposition(self)
#    1325 def decomposition(self) -> list["Operator"]:
#    1326     r"""Representation of the operator as a product of other operators.
#    1327
#    1328     .. math:: O = O_1 O_2 \dots O_n
#    (...)
#    1335         list[Operator]: decomposition of the operator
#    1336     """
# -> 1337     return self.compute_decomposition(
#    1338         *self.parameters, wires=self.wires, **self.hyperparameters
#    1339     )
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/templates/layers/random.py:249, in RandomLayers.compute_decomposition(weights, wires, ratio_imprim, imprimitive, rotations, seed)
#     247     gate = rng.choice(rotations)
#     248     rnd_wire = wires.select_random(1, seed=rng)
# --> 249     op_list.append(gate(weights[l][i], wires=rnd_wire))
#     250     i += 1
#     252 else:
#     253     # apply the entangler to two random wires
#
# File ~/.local/perlmutter/pytorch2.3.1/lib/python3.11/site-packages/pennylane/capture/capture_meta.py:89, in CaptureMeta.__call__(cls, *args, **kwargs)
#      85 if enabled():
#      86     # when tracing is enabled, we want to
#      87     # use bind to construct the class if we want class construction to add it to the jaxpr
#      88     return cls._primitive_bind_call(*args, **kwargs)
# ---> 89 return type.__call__(cls, *args, **kwargs)
#
# TypeError: U3.__init__() missing 2 required positional arguments: 'phi' and 'delta'

# %%
loss_func = torch.nn.L1Loss()

# %%
class HybridModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.clayer_1 = torch.nn.Linear(2, 20)
        # block one
        self.qlayer_1 = qml.qnn.TorchLayer(qnode, weight_shapes)
        # block two
        self.qlayer_2 = qml.qnn.TorchLayer(qnode, weight_shapes)
        self.clayer_2 = torch.nn.Linear(20, 2)
        self.softmax = torch.nn.Softmax(dim=1)

    def forward(self, x):
        x = self.clayer_1(x)
        x_1, x_2 = torch.split(x, 10, dim=1)
        x_1 = self.qlayer_1(x_1)
        x_2 = self.qlayer_2(x_2)
        x = torch.cat([x_1, x_2], axis=1)
        x = self.clayer_2(x)
        return self.softmax(x)

model = HybridModel()

# %%
from sklearn.model_selection import train_test_split

# %%
X = torch.tensor(X, requires_grad=True).float()
y_hot = y_hot.float()

batch_size = 5
batches = 200 // batch_size

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=149)
# Convert data to PyTorch tensors
X_train = torch.tensor(X_train, requires_grad=True).float()
y_ = torch.unsqueeze(torch.tensor(y_train), 1)  # used for one-hot encoded labels
y_train_hot = torch.scatter(torch.zeros((280, 2)), 1, y_, 1)
y_train_hot = y_train_hot.float()

X_test = torch.tensor(X_test, requires_grad=True).float()
y_ = torch.unsqueeze(torch.tensor(y_test), 1)  # used for one-hot encoded labels
y_test_hot = torch.scatter(torch.zeros((120, 2)), 1, y_, 1)
y_test_hot = y_test_hot.float()

train_dataset = TensorDataset(X_train, y_train_hot)
test_dataset = TensorDataset(X_test, y_test_hot)

train_loader = DataLoader(train_dataset, batch_size=5, shuffle=True, drop_last=True)
test_loader = DataLoader(test_dataset, batch_size=5, shuffle=True, drop_last=True)

optimizer_hybrid = torch.optim.Adam(model.parameters(), lr=0.0004)

train_acc_history = []
test_acc_history = []

epochs = 100

for epoch in range(epochs):
    train_running_loss = 0
    test_running_loss = 0
    for xs, ys in train_loader:
        opt.zero_grad()

        loss_evaluated = loss_func(model(xs), ys)
        loss_evaluated.backward()

        opt.step()

        train_running_loss += loss_evaluated.item()
        
    train_avg_loss = train_running_loss / batches

    print(f"Train - Epoch {epoch + 1}: Loss: {train_avg_loss:.4f}")

    # Calculate train accuracy
    y_pred_train = model(X_train)
    predictions_train = torch.argmax(y_pred_train, axis=1).detach().numpy()

    correct_train = [1 if p == p_true else 0 for p, p_true in zip(predictions_train, y_train)]
    train_accuracy = sum(correct_train) / len(correct_train)
    print(f"Train Accuracy: {train_accuracy * 100:.2f}%")
    train_acc_history.append(train_accuracy)
    
    # Calculate testmodel.eval()
    with torch.no_grad():
        y_pred_test = model(X_test)
        predictions_test = torch.argmax(y_pred_test, axis=1).detach().numpy()
        correct_test = [1 if p == p_true else 0 for p, p_true in zip(predictions_test, y_test)]
        test_accuracy = sum(correct_test) / len(correct_test)
        print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
        test_acc_history.append(test_accuracy)
# Out:
# /tmp/ipykernel_2121869/2335851833.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X = torch.tensor(X, requires_grad=True).float()
# /tmp/ipykernel_2121869/2335851833.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_train = torch.tensor(X_train
# Train Accuracy: 99.64%
# Test Accuracy: 100.00%
# Train - Epoch 60: Loss: 0.0507
# Train Accuracy: 94.29%
# Test Accuracy: 95.00%
# Train - Epoch 61: Loss: 0.0394
# Train Accuracy: 96.07%
# Test Accuracy: 96.67%
# Train - Epoch 62: Loss: 0.0243
# Train Accuracy: 99.64%
# Test Accuracy: 100.00%
# Train - Epoch 63: Loss: 0.0083
# Train Accuracy: 98.93%
# Test Accuracy: 99.17%
# Train - Epoch 64: Loss: 0.0032
# Train Accuracy: 99.29%
# Test Accuracy: 99.17%
# Train - Epoch 65: Loss: 0.0525
# Train Accuracy: 99.64%
# Test Accuracy: 99.17%
# Train - Epoch 66: Loss: 0.0839
# Train Accuracy: 78.57%
# Test Accuracy: 71.67%
# Train - Epoch 67: Loss: 0.0594
# Train Accuracy: 98.93%
# Test Accuracy: 99.17%
# Train - Epoch 68: Loss: 0.0387
# Train Accuracy: 98.93%
# Test Accuracy: 98.33%
# Train - Epoch 69: Loss: 0.0413
# Train Accuracy: 99.29%
# Test Accuracy: 100.00%
# Train - Epoch 70: Loss: 0.0172
# Train Accuracy: 98.57%
# Test Accuracy: 98.33%
# Train - Epoch 71: Loss: 0.0214
# Train Accuracy: 98.93%
# Test Accuracy: 99.17%
# Train - Epoch 72: Loss: 0.0329
# Train Accuracy: 97.50%
# Test Accuracy: 97.50%
# Train - Epoch 73: Loss: 0.0131
# Train Accuracy: 98.93%
# Test Accuracy: 97.50%
# Train - Epoch 74: Loss: 0.0136
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 75: Loss: 0.0110
# Train Accuracy: 97.50%
# Test Accuracy: 97.50%
# Train - Epoch 76: Loss: 0.0293
# Train Accuracy: 99.64%
# Test Accuracy: 99.17%
# Train - Epoch 77: Loss: 0.0046
# Train Accuracy: 98.57%
# Test Accuracy: 98.33%
# Train - Epoch 78: Loss: 0.0161
# Train Accuracy: 98.93%
# Test Accuracy: 99.17%
# Train - Epoch 79: Loss: 0.0169
# Train Accuracy: 96.79%
# Test Accuracy: 96.67%
# Train - Epoch 80: Loss: 0.0115
# Train Accuracy: 99.29%
# Test Accuracy: 100.00%
# Train - Epoch 81: Loss: 0.0295
# Train Accuracy: 98.93%
# Test Accuracy: 99.17%
# Train - Epoch 82: Loss: 0.0275
# Train Accuracy: 99.29%
# Test Accuracy: 99.17%
# Train - Epoch 83: Loss: 0.0054
# Train Accuracy: 100.00%
# Test Accuracy: 100.00%
# Train - Epoch 84: Loss: 0.0013
# Train Accuracy: 99.64%
# Test Accuracy: 99.17%
# Train - Epoch 85: Loss: 0.0318
# Train Accuracy: 96.79%
# Test Accuracy: 97.50%
# Train - Epoch 86: Loss: 0.0637
# Train Accuracy: 99.64%
# Test Accuracy: 100.00%
# Train - Epoch 87: Loss: 0.0252
# Train Accuracy: 96.07%
# Test Accuracy: 97.50%
# Train - Epoch 88: Loss: 0.0190
# Train Accuracy: 98.21%
# Test Accuracy: 97.50%
# Train - Epoch 89: Loss: 0.0271
# Train Accuracy: 99.29%
# Test Accuracy: 99.17%
# Train - Epoch 90: Loss: 0.0232
# Train Accuracy: 97.86%
# Test Accuracy: 95.83%
# Train - Epoch 91: Loss: 0.0210
# Train Accuracy: 99.64%
# Test Accuracy: 99.17%
# Train - Epoch 92: Loss: 0.0158
# Train Accuracy: 100.00%
# Test Accuracy: 99.17%
# Train - Epoch 93: Loss: 0.0308
# Train Accuracy: 99.64%
# Test Accuracy: 99.17%
# Train - Epoch 94: Loss: 0.0195
# Train Accuracy: 99.29%
# Test Accuracy: 99.17%
# Train - Epoch 95: Loss: 0.0158
# Train Accuracy: 99.29%
# Test Accuracy: 98.33%
# Train - Epoch 96: Loss: 0.0290
# Train Accuracy: 99.29%
# Test Accuracy: 99.17%
# Train - Epoch 97: Loss: 0.0223
# Train Accuracy: 98.57%
# Test Accuracy: 99.17%
# Train - Epoch 98: Loss: 0.0213
# Train Accuracy: 98.93%
# Test Accuracy: 99.17%
# Train - Epoch 99: Loss: 0.0116
# Train Accuracy: 97.86%
# Test Accuracy: 98.33%
# Train - Epoch 100: Loss: 0.0326
# Train Accuracy: 99.29%
# Test Accuracy: 99.17%

# %%
# Plotting the training and testing accuracies
plt.plot(train_acc_history, label='Train Accuracy')
plt.plot(test_acc_history, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Testing Accuracy over Epochs')
plt.tight_layout()
plt.show()

# %%
# Original dataset plot
c = ["#1f77b4" if y_ == 0 else "#ff7f0e" for y_ in y]  # colors for each class
plt.scatter(X[:, 0], X[:, 1], c=c, alpha=0.5, label='Original Data')

# Highlight test points
# Correct predictions in green, incorrect in red
for i in test_indices:
    if y[i] == predictions[i]:
        plt.scatter(X[i, 0], X[i, 1], c='green', edgecolor='k', label='Correct Prediction' if i == test_indices[0] else "")
    else:
        plt.scatter(X[i, 0], X[i, 1], c='red', edgecolor='k', label='Incorrect Prediction' if i == test_indices[0] else "")

plt.axis("off")
plt.legend()
plt.show()

# %%
seconds = time.time()
print("Time in seconds since end of run:", seconds)
local_time = time.ctime(seconds)
print(local_time)
# Out:
# Time in seconds since end of run: 1708813854.662059
# Sat Feb 24 15:30:54 2024
